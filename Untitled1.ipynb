# %%
#W2A1
print ("Hello World")
# Out:
# Hello World

# %%
#W2A2
name = input ("Nhập tên của bạn: ")
print ("Xin chào", name)
# Out:
# Nhập tên của bạn: Phong
# Xin chào Phong

# %%
#W2A10
a,b,c = input ("Nhập tên của các bạn: ").split()
print ("Hi",c,",",b,"and",a)
# Out:
# Nhập tên của các bạn: Ngoan Xinh Yêu
# Hi Yêu , Xinh and Ngoan

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
for i in range (1,6,2):
  print ("*"*i)
# Out:
# *
# ***
# *****

# %%
#W2A18
print (" ### # #  ### ###")
print ("  #  #  #  #   #")
print ("  #  #   # #   #")
print ("  #  #  #  #   #")
print ("  #  # #   #   #")
# Out:
#  ### # #  ### ###
#   #  #  #  #   #
#   #  #   # #   #
#   #  #  #  #   #
#   #  # #   #   #

# %%
#W2A19
print ("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print ("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(10):
  print ("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
